# %%
import json
import requests

url = "https://raw.githubusercontent.com/clinc/oos-eval/master/data/data_small.json"
response = requests.get(url)
data = response.json()

print("Available splits:", data.keys())
print("Number of training examples:", len(data["train"]))
print("Number of validation examples:", len(data["val"]))
print("Number of test examples:", len(data["test"]))

print("\nSample training examples (utterance, intent):")
for example in data["train"][:3]:
    print(example)
# Out:
# Available splits: dict_keys(['oos_val', 'val', 'train', 'oos_test', 'test', 'oos_train'])
# Number of training examples: 7500
# Number of validation examples: 3000
# Number of test examples: 4500
#
# Sample training examples (utterance, intent):
# ['can you walk me through setting up direct deposits to my bank of internet savings account', 'direct_deposit']
# ['i want to switch to direct deposit', 'direct_deposit']
# ['set up direct deposit for me', 'direct_deposit']

# %%
train_data = data["train"] + data["oos_train"]
val_data   = data["val"]   + data["oos_val"]
test_data  = data["test"]  + data["oos_test"]

print("Train size:", len(train_data))
print("Val size:", len(val_data))
print("Test size:", len(test_data))
# Out:
# Train size: 7600
# Val size: 3100
# Test size: 5500

# %%
import pandas as pd
import numpy as np


train_df = pd.DataFrame(train_data, columns=["text","intent"])
val_df   = pd.DataFrame(val_data, columns=["text","intent"])
test_df  = pd.DataFrame(test_data, columns=["text","intent"])

print("\nSample training data:")
print(train_df.tail())
# Out:
# Sample training data:
#                                                    text intent
# 7595  what percentage of species display cold bloode...    oos
# 7596              what does it mean to be an alpha male    oos
# 7597                      what animals have alpha males    oos
# 7598                      why do males want to be alpha    oos
# 7599  what's the average battery life of an android ...    oos

# %%
num_intents = train_df["intent"].nunique()
print("Number of unique intents:", num_intents)
print("\nSample intents:", train_df["intent"].unique()[:10])
# Out:
# Number of unique intents: 151
#
# Sample intents: ['direct_deposit' 'carry_on' 'whisper_mode' 'text' 'recipe' 'smart_home'
#  'who_do_you_work_for' 'rewards_balance' 'restaurant_reservation'
#  'travel_notification']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

train_labels = label_encoder.fit_transform(train_df["intent"])
val_labels   = label_encoder.transform(val_df["intent"])
test_labels  = label_encoder.transform(test_df["intent"])

print("Number of unique classes:", len(label_encoder.classes_))
print("Sample classes:", label_encoder.classes_[:10])
print("Encoded sample:", train_labels[:10])
# Out:
# Number of unique classes: 151
# Sample classes: ['accept_reservations' 'account_blocked' 'alarm' 'application_status'
#  'apr' 'are_you_a_bot' 'balance' 'bill_balance' 'bill_due' 'book_flight']
# Encoded sample: [35 35 35 35 35 35 35 35 35 35]

# %%
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression

sbert_model = SentenceTransformer("all-MiniLM-L6-v2")
train_vecs = sbert_model.encode(train_df["text"].tolist(), convert_to_numpy=True)
val_vecs   = sbert_model.encode(val_df["text"].tolist(), convert_to_numpy=True)
test_vecs  = sbert_model.encode(test_df["text"].tolist(), convert_to_numpy=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=2000)
clf.fit(train_vecs, train_labels)
# Out:
# LogisticRegression(max_iter=2000)

# %%
from sklearn.metrics import classification_report, accuracy_score

val_preds = clf.predict(val_vecs)
val_acc = accuracy_score(val_labels, val_preds)
print(f"Validation Accuracy: {val_acc:.3f}\n")

print("Validation Classification Report:")
print(classification_report(val_labels, val_preds, target_names=label_encoder.classes_))
print("Validation Classification Report")

test_preds = clf.predict(test_vecs)
test_acc = accuracy_score(test_labels, test_preds)
print(f"Test Accuracy: {test_acc:.3f}\n")

print("Test Classification Report:")
print(classification_report(test_labels, test_preds, target_names=label_encoder.classes_))
print("Test Classification Report")
# Out:
# Validation Accuracy: 0.924
#
# Validation Classification Report:
#                            precision    recall  f1-score   support
#
#       accept_reservations       0.80      1.00      0.89        20
#           account_blocked       1.00      0.95      0.97        20
#                     alarm       1.00      1.00      1.00        20
#        application_status       0.95      1.00      0.98        20
#                       apr       1.00      1.00      1.00        20
#             are_you_a_bot       0.95      0.95      0.95        20
#                   balance       0.89      0.85      0.87        20
#              bill_balance       1.00      0.85      0.92        20
#                  bill_due       1.00      1.00      1.00        20
#               book_flight       1.00      1.00      1.00        20
#                book_hotel       0.95      0.90      0.92        20
#                calculator       0.87      1.00      0.93        20
#                  calendar       0.90      0.95      0.93        20
#           calendar_update       1.00      1.00      1.00        20
#                  calories       1.00      1.00      1.00        20
#                    cancel       0.86      0.90      0.88        20
#        cancel_reservation       1.00      0.95      0.97        20
#                car_rental       1.00      1.00      1.00        20
#             card_declined       0.95      1.00      0.98        20
#                  carry_on       1.00      1.00      1.00        20
#             change_accent       1.00      0.80      0.89        20
#            change_ai_name       0.78      0.70      0.74        20
#           change_language       1.00      0.95      0.97        20
#              change_speed       1.00      1.00      1.00        20
#          change_user_name       0.65      0.75      0.70        20
#             change_volume       1.00      1.00      1.00        20
#       confirm_reservation       0.90      0.90      0.90        20
#                 cook_time       0.91      1.00      0.95        20
#              credit_limit       1.00      0.95      0.97        20
#       credit_limit_change       1.00      1.00      1.00        20
#              credit_score       1.00      0.95      0.97        20
#          current_location       1.00      0.80      0.89        20
#              damaged_card       0.95      1.00      0.98        20
#                      date       1.00      1.00      1.00        20
#                definition       0.73      0.95      0.83        20
#            direct_deposit       0.95      1.00      0.98        20
#                directions       0.90      0.90      0.90        20
#                  distance       0.95      0.95      0.95        20
#          do_you_have_pets       0.80      1.00      0.89        20
#             exchange_rate       0.91      1.00      0.95        20
#           expiration_date       1.00      0.90      0.95        20
#                find_phone       1.00      1.00      1.00        20
#             flight_status       1.00      1.00      1.00        20
#                 flip_coin       1.00      1.00      1.00        20
#                 food_last       1.00      1.00      1.00        20
#            freeze_account       0.83      1.00      0.91        20
#                  fun_fact       0.90      0.90      0.90        20
#                       gas       0.95      0.95      0.95        20
#                  gas_type       1.00      0.95      0.97        20
#                   goodbye       0.82      0.90      0.86        20
#                  greeting       0.79      0.95      0.86        20
#                  how_busy       0.86      0.95      0.90        20
#           how_old_are_you       0.95      1.00      0.98        20
#      improve_credit_score       1.00      1.00      1.00        20
#                    income       0.86      0.90      0.88        20
#   ingredient_substitution       0.86      0.95      0.90        20
#          ingredients_list       0.91      1.00      0.95        20
#                 insurance       1.00      0.75      0.86        20
#          insurance_change       0.77      1.00      0.87        20
#             interest_rate       1.00      0.95      0.97        20
#        international_fees       0.95      1.00      0.98        20
#        international_visa       1.00      1.00      1.00        20
#                jump_start       1.00      1.00      1.00        20
#          last_maintenance       1.00      0.70      0.82        20
#              lost_luggage       1.00      1.00      1.00        20
#                 make_call       0.95      0.95      0.95        20
#                     maybe       0.95      0.90      0.92        20
#           meal_suggestion       0.90      0.95      0.93        20
#           meaning_of_life       0.90      0.95      0.93        20
#    measurement_conversion       0.95      0.95      0.95        20
#          meeting_schedule       0.95      1.00      0.98        20
#               min_payment       0.95      1.00      0.98        20
#                       mpg       1.00      1.00      1.00        20
#                  new_card       1.00      0.85      0.92        20
#              next_holiday       0.90      0.95      0.93        20
#                 next_song       1.00      0.95      0.97        20
#                        no       0.85      0.85      0.85        20
#            nutrition_info       0.90      0.90      0.90        20
#            oil_change_how       0.95      1.00      0.98        20
#           oil_change_when       0.71      1.00      0.83        20
#                       oos       0.84      0.59      0.69       100
#                     order       0.72      0.90      0.80        20
#              order_checks       1.00      1.00      1.00        20
#              order_status       1.00      0.90      0.95        20
#                  pay_bill       0.95      0.95      0.95        20
#                    payday       1.00      0.90      0.95        20
#                pin_change       1.00      1.00      1.00        20
#                play_music       0.79      0.95      0.86        20
#                 plug_type       1.00      1.00      1.00        20
#               pto_balance       0.90      0.95      0.93        20
#               pto_request       1.00      1.00      1.00        20
#        pto_request_status       1.00      0.95      0.97        20
#                  pto_used       0.95      0.90      0.92        20
#                    recipe       0.95      0.95      0.95        20
#            redeem_rewards       0.94      0.85      0.89        20
#                  reminder       1.00      0.75      0.86        20
#           reminder_update       0.89      0.85      0.87        20
#                    repeat       0.89      0.85      0.87        20
# replacement_card_duration       0.79      0.95      0.86        20
#              report_fraud       1.00      0.90      0.95        20
#          report_lost_card       0.95      0.95      0.95        20
#            reset_settings       1.00      1.00      1.00        20
#    restaurant_reservation       0.92      0.60      0.73        20
#        restaurant_reviews       1.00      0.90      0.95        20
#     restaurant_suggestion       0.79      0.95      0.86        20
#           rewards_balance       0.80      1.00      0.89        20
#                 roll_dice       1.00      1.00      1.00        20
#             rollover_401k       1.00      1.00      1.00        20
#                   routing       1.00      1.00      1.00        20
#      schedule_maintenance       1.00      0.90      0.95        20
#          schedule_meeting       1.00      1.00      1.00        20
#            share_location       1.00      1.00      1.00        20
#             shopping_list       0.90      0.45      0.60        20
#      shopping_list_update       0.58      0.70      0.64        20
#                smart_home       0.87      1.00      0.93        20
#                  spelling       0.91      1.00      0.95        20
#          spending_history       0.95      1.00      0.98        20
#               sync_device       0.95      1.00      0.98        20
#                     taxes       0.91      1.00      0.95        20
#                 tell_joke       0.95      1.00      0.98        20
#                      text       1.00      0.85      0.92        20
#                 thank_you       0.91      1.00      0.95        20
#                      time       0.95      1.00      0.98        20
#                     timer       1.00      0.95      0.97        20
#                  timezone       1.00      1.00      1.00        20
#               tire_change       0.95      1.00      0.98        20
#             tire_pressure       1.00      1.00      1.00        20
#                 todo_list       0.77      0.50      0.61        20
#          todo_list_update       0.67      0.90      0.77        20
#                   traffic       0.91      1.00      0.95        20
#              transactions       0.89      0.80      0.84        20
#                  transfer       0.95      1.00      0.98        20
#                 translate       0.95      0.95      0.95        20
#              travel_alert       1.00      1.00      1.00        20
#       travel_notification       0.90      0.95      0.93        20
#         travel_suggestion       0.89      0.80      0.84        20
#                      uber       0.95      1.00      0.98        20
#           update_playlist       1.00      0.85      0.92        20
#                 user_name       0.78      0.70      0.74        20
#                  vaccines       1.00      1.00      1.00        20
#                        w2       1.00      1.00      1.00        20
#                   weather       0.91      1.00      0.95        20
#     what_are_your_hobbies       1.00      0.90      0.95        20
#        what_can_i_ask_you       0.62      1.00      0.77        20
#         what_is_your_name       0.79      0.75      0.77        20
#                 what_song       1.00      1.00      1.00        20
#        where_are_you_from       0.95      0.95      0.95        20
#              whisper_mode       1.00      1.00      1.00        20
#       who_do_you_work_for       1.00      1.00      1.00        20
#              who_made_you       1.00      0.95      0.97        20
#                       yes       1.00      0.70      0.82        20
#
#                  accuracy                           0.92      3100
#                 macro avg       0.93      0.93      0.93      3100
#              weighted avg       0.93      0.92      0.92      3100
#
# Validation Classification Report
# Test Accuracy: 0.852
#
# Test Classification Report:
#                            precision    recall  f1-score   support
#
#       accept_reservations       0.84      0.90      0.87        30
#           account_blocked       0.93      0.83      0.88        30
#                     alarm       1.00      1.00      1.00        30
#        application_status       1.00      1.00      1.00        30
#                       apr       0.93      0.93      0.93        30
#             are_you_a_bot       0.94      1.00      0.97        30
#                   balance       0.84      0.90      0.87        30
#              bill_balance       0.77      0.90      0.83        30
#                  bill_due       0.88      0.93      0.90        30
#               book_flight       0.83      1.00      0.91        30
#                book_hotel       0.88      1.00      0.94        30
#                calculator       0.67      0.97      0.79        30
#                  calendar       0.82      0.77      0.79        30
#           calendar_update       0.79      0.90      0.84        30
#                  calories       0.88      1.00      0.94        30
#                    cancel       0.71      0.97      0.82        30
#        cancel_reservation       0.97      1.00      0.98        30
#                car_rental       0.67      0.97      0.79        30
#             card_declined       1.00      0.93      0.97        30
#                  carry_on       0.97      0.97      0.97        30
#             change_accent       0.97      1.00      0.98        30
#            change_ai_name       0.43      0.43      0.43        30
#           change_language       0.79      1.00      0.88        30
#              change_speed       0.91      0.97      0.94        30
#          change_user_name       0.55      0.60      0.57        30
#             change_volume       1.00      0.90      0.95        30
#       confirm_reservation       0.97      0.93      0.95        30
#                 cook_time       0.80      0.93      0.86        30
#              credit_limit       0.91      1.00      0.95        30
#       credit_limit_change       0.97      1.00      0.98        30
#              credit_score       0.94      1.00      0.97        30
#          current_location       0.79      1.00      0.88        30
#              damaged_card       0.91      1.00      0.95        30
#                      date       0.86      1.00      0.92        30
#                definition       0.77      1.00      0.87        30
#            direct_deposit       0.83      1.00      0.91        30
#                directions       0.62      0.87      0.72        30
#                  distance       0.73      0.80      0.76        30
#          do_you_have_pets       0.79      1.00      0.88        30
#             exchange_rate       0.94      0.97      0.95        30
#           expiration_date       0.91      0.97      0.94        30
#                find_phone       0.83      1.00      0.91        30
#             flight_status       0.91      1.00      0.95        30
#                 flip_coin       0.97      1.00      0.98        30
#                 food_last       0.83      0.97      0.89        30
#            freeze_account       0.77      1.00      0.87        30
#                  fun_fact       0.80      0.93      0.86        30
#                       gas       1.00      1.00      1.00        30
#                  gas_type       0.91      1.00      0.95        30
#                   goodbye       0.89      0.80      0.84        30
#                  greeting       0.78      0.97      0.87        30
#                  how_busy       0.84      0.90      0.87        30
#           how_old_are_you       0.85      0.97      0.91        30
#      improve_credit_score       0.91      1.00      0.95        30
#                    income       0.84      0.90      0.87        30
#   ingredient_substitution       0.79      1.00      0.88        30
#          ingredients_list       0.60      0.83      0.69        30
#                 insurance       0.94      0.97      0.95        30
#          insurance_change       0.94      1.00      0.97        30
#             interest_rate       0.76      0.87      0.81        30
#        international_fees       0.86      1.00      0.92        30
#        international_visa       0.94      1.00      0.97        30
#                jump_start       0.94      1.00      0.97        30
#          last_maintenance       0.85      0.93      0.89        30
#              lost_luggage       0.94      1.00      0.97        30
#                 make_call       0.58      1.00      0.73        30
#                     maybe       0.97      0.97      0.97        30
#           meal_suggestion       0.93      0.87      0.90        30
#           meaning_of_life       0.97      0.97      0.97        30
#    measurement_conversion       0.94      1.00      0.97        30
#          meeting_schedule       0.96      0.83      0.89        30
#               min_payment       0.97      1.00      0.98        30
#                       mpg       0.83      1.00      0.91        30
#                  new_card       0.76      0.93      0.84        30
#              next_holiday       0.81      1.00      0.90        30
#                 next_song       1.00      0.97      0.98        30
#                        no       0.86      1.00      0.92        30
#            nutrition_info       0.88      1.00      0.94        30
#            oil_change_how       0.88      1.00      0.94        30
#           oil_change_when       0.88      0.93      0.90        30
#                       oos       0.98      0.48      0.64      1000
#                     order       0.56      0.80      0.66        30
#              order_checks       0.94      1.00      0.97        30
#              order_status       0.81      0.97      0.88        30
#                  pay_bill       0.83      0.97      0.89        30
#                    payday       1.00      0.97      0.98        30
#                pin_change       0.93      0.83      0.88        30
#                play_music       0.71      0.90      0.79        30
#                 plug_type       0.97      1.00      0.98        30
#               pto_balance       0.93      0.93      0.93        30
#               pto_request       0.96      0.80      0.87        30
#        pto_request_status       0.79      0.90      0.84        30
#                  pto_used       0.77      1.00      0.87        30
#                    recipe       0.72      0.93      0.81        30
#            redeem_rewards       0.96      0.80      0.87        30
#                  reminder       1.00      0.93      0.97        30
#           reminder_update       0.75      0.80      0.77        30
#                    repeat       0.90      0.93      0.92        30
# replacement_card_duration       0.96      0.87      0.91        30
#              report_fraud       0.84      0.90      0.87        30
#          report_lost_card       1.00      0.87      0.93        30
#            reset_settings       1.00      1.00      1.00        30
#    restaurant_reservation       0.79      0.90      0.84        30
#        restaurant_reviews       0.80      0.80      0.80        30
#     restaurant_suggestion       0.70      0.93      0.80        30
#           rewards_balance       0.83      1.00      0.91        30
#                 roll_dice       1.00      1.00      1.00        30
#             rollover_401k       1.00      1.00      1.00        30
#                   routing       0.97      1.00      0.98        30
#      schedule_maintenance       0.74      0.87      0.80        30
#          schedule_meeting       0.81      1.00      0.90        30
#            share_location       0.70      0.93      0.80        30
#             shopping_list       0.79      0.50      0.61        30
#      shopping_list_update       0.53      0.83      0.65        30
#                smart_home       0.53      0.83      0.65        30
#                  spelling       0.78      0.93      0.85        30
#          spending_history       0.74      0.97      0.84        30
#               sync_device       0.71      1.00      0.83        30
#                     taxes       0.94      1.00      0.97        30
#                 tell_joke       0.91      1.00      0.95        30
#                      text       0.71      0.90      0.79        30
#                 thank_you       0.82      0.93      0.88        30
#                      time       0.76      0.93      0.84        30
#                     timer       0.93      0.93      0.93        30
#                  timezone       0.97      0.97      0.97        30
#               tire_change       0.94      1.00      0.97        30
#             tire_pressure       1.00      1.00      1.00        30
#                 todo_list       0.89      0.83      0.86        30
#          todo_list_update       0.62      0.80      0.70        30
#                   traffic       0.86      1.00      0.92        30
#              transactions       0.96      0.80      0.87        30
#                  transfer       0.93      0.93      0.93        30
#                 translate       1.00      0.87      0.93        30
#              travel_alert       0.81      1.00      0.90        30
#       travel_notification       0.94      1.00      0.97        30
#         travel_suggestion       0.56      1.00      0.71        30
#                      uber       0.94      1.00      0.97        30
#           update_playlist       0.87      0.90      0.89        30
#                 user_name       0.88      0.73      0.80        30
#                  vaccines       0.83      1.00      0.91        30
#                        w2       0.97      1.00      0.98        30
#                   weather       0.70      1.00      0.82        30
#     what_are_your_hobbies       0.85      0.93      0.89        30
#        what_can_i_ask_you       0.83      0.97      0.89        30
#         what_is_your_name       0.82      0.90      0.86        30
#                 what_song       0.88      1.00      0.94        30
#        where_are_you_from       1.00      0.93      0.97        30
#              whisper_mode       0.86      1.00      0.92        30
#       who_do_you_work_for       0.81      0.83      0.82        30
#              who_made_you       0.86      1.00      0.92        30
#                       yes       0.96      0.87      0.91        30
#
#                  accuracy                           0.85      5500
#                 macro avg       0.85      0.93      0.89      5500
#              weighted avg       0.88      0.85      0.84      5500
#
# Test Classification Report

# %% [markdown]
# # OOS Handling

# %% [markdown]
# 1-Finding OOS and retrieve the probability distribution we got from logistic regression across all our classes :

# %%
oos_name = "oos"
class_names = label_encoder.classes_
oos_idx = list(class_names).index(oos_name)

val_probs = clf.predict_proba(val_vecs)
test_probs = clf.predict_proba(test_vecs)

# %% [markdown]
# 2-We make  oos our ground truth ; 1 = OOS, 0 = in-domain :

# %%
y_true_val_binary = (val_labels == oos_idx).astype(int)
y_true_test_binary = (test_labels == oos_idx).astype(int)

# %% [markdown]
# 3- This code finds the best OOS rejection threshold by testing values from 0.1 to 0.9. For each threshold, if the model’s max probability is below it, the sample is marked OOS; otherwise it’s in-domain. Precision, recall, and F1 are computed, and the threshold with the highest F1 on validation is selected as the best trade-off, then used on the test set.

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support

thresholds = np.linspace(0.1, 0.9, 9)
best_f1, best_th = -1, None

for th in thresholds:
    max_probs = val_probs.max(axis=1)
    y_pred_val_binary = (max_probs < th).astype(int)
    prec, rec, f1, _ = precision_recall_fscore_support(
        y_true_val_binary, y_pred_val_binary, average="binary", zero_division=0
    )
    print(f"Threshold {th:.2f} -> Precision: {prec:.3f}, Recall: {rec:.3f}, F1: {f1:.3f}")
    if f1 > best_f1:
        best_f1, best_th = f1, th

print(f"\nBest threshold on val: {best_th:.2f} with F1: {best_f1:.3f}")
# Out:
# Threshold 0.10 -> Precision: 0.327, Recall: 0.330, F1: 0.328
# Threshold 0.20 -> Precision: 0.218, Recall: 0.770, F1: 0.340
# Threshold 0.30 -> Precision: 0.143, Recall: 0.890, F1: 0.246
# Threshold 0.40 -> Precision: 0.096, Recall: 0.940, F1: 0.175
# Threshold 0.50 -> Precision: 0.070, Recall: 0.990, F1: 0.131
# Threshold 0.60 -> Precision: 0.053, Recall: 1.000, F1: 0.100
# Threshold 0.70 -> Precision: 0.042, Recall: 1.000, F1: 0.081
# Threshold 0.80 -> Precision: 0.035, Recall: 1.000, F1: 0.068
# Threshold 0.90 -> Precision: 0.032, Recall: 1.000, F1: 0.063
#
# Best threshold on val: 0.20 with F1: 0.340

# %% [markdown]
# Next we apply the best threshold to flag OOS samples on validation and test sets.
# It classifies each sample as OOS if its max prediction probability is below the threshold.
# classification_report then shows precision, recall, and F1 for OOS detection.

# %%
from sklearn.metrics import classification_report

max_probs_val = val_probs.max(axis=1)
y_pred_val_binary = (max_probs_val < best_th).astype(int)
print("\nBinary OOS detection on val:")
print(classification_report(y_true_val_binary, y_pred_val_binary,
                            target_names=["In-domain", "OOS"], zero_division=0))

max_probs_test = test_probs.max(axis=1)
y_pred_test_binary = (max_probs_test < best_th).astype(int)
print("\nBinary OOS detection on test:")
print(classification_report(y_true_test_binary, y_pred_test_binary,
                            target_names=["In-domain", "OOS"], zero_division=0))
# Out:
# Binary OOS detection on val:
#               precision    recall  f1-score   support
#
#    In-domain       0.99      0.91      0.95      3000
#          OOS       0.22      0.77      0.34       100
#
#     accuracy                           0.90      3100
#    macro avg       0.60      0.84      0.64      3100
# weighted avg       0.97      0.90      0.93      3100
#
#
# Binary OOS detection on test:
#               precision    recall  f1-score   support
#
#    In-domain       0.95      0.91      0.93      4500
#          OOS       0.67      0.77      0.72      1000
#
#     accuracy                           0.89      5500
#    macro avg       0.81      0.84      0.82      5500
# weighted avg       0.90      0.89      0.89      5500

# %%
test_preds_labels = clf.predict(test_vecs)

test_preds_names = np.array([class_names[p] for p in test_preds_labels])
test_preds_names[y_pred_test_binary == 1] = oos_name

test_true_names = np.array([class_names[t] for t in test_labels])

print("\nFull classification report on test (with OOS threshold):")
print(classification_report(test_true_names, test_preds_names, zero_division=0))
# Out:
# Full classification report on test (with OOS threshold):
#                            precision    recall  f1-score   support
#
#       accept_reservations       0.90      0.90      0.90        30
#           account_blocked       0.96      0.83      0.89        30
#                     alarm       1.00      0.93      0.97        30
#        application_status       1.00      1.00      1.00        30
#                       apr       0.93      0.93      0.93        30
#             are_you_a_bot       1.00      0.93      0.97        30
#                   balance       0.88      0.77      0.82        30
#              bill_balance       0.96      0.77      0.85        30
#                  bill_due       0.96      0.90      0.93        30
#               book_flight       1.00      0.87      0.93        30
#                book_hotel       1.00      0.87      0.93        30
#                calculator       0.87      0.87      0.87        30
#                  calendar       0.95      0.70      0.81        30
#           calendar_update       0.86      0.83      0.85        30
#                  calories       1.00      0.97      0.98        30
#                    cancel       0.96      0.90      0.93        30
#        cancel_reservation       1.00      1.00      1.00        30
#                car_rental       0.90      0.87      0.88        30
#             card_declined       1.00      0.80      0.89        30
#                  carry_on       1.00      0.90      0.95        30
#             change_accent       0.97      1.00      0.98        30
#            change_ai_name       0.63      0.40      0.49        30
#           change_language       0.90      0.93      0.92        30
#              change_speed       0.94      0.97      0.95        30
#          change_user_name       0.71      0.50      0.59        30
#             change_volume       1.00      0.80      0.89        30
#       confirm_reservation       0.96      0.90      0.93        30
#                 cook_time       0.97      0.93      0.95        30
#              credit_limit       0.93      0.83      0.88        30
#       credit_limit_change       1.00      0.97      0.98        30
#              credit_score       1.00      1.00      1.00        30
#          current_location       0.94      0.97      0.95        30
#              damaged_card       0.96      0.90      0.93        30
#                      date       1.00      1.00      1.00        30
#                definition       0.93      0.83      0.88        30
#            direct_deposit       0.88      1.00      0.94        30
#                directions       0.68      0.57      0.62        30
#                  distance       0.86      0.63      0.73        30
#          do_you_have_pets       0.94      1.00      0.97        30
#             exchange_rate       0.97      0.97      0.97        30
#           expiration_date       0.97      0.97      0.97        30
#                find_phone       1.00      0.97      0.98        30
#             flight_status       0.97      1.00      0.98        30
#                 flip_coin       1.00      1.00      1.00        30
#                 food_last       1.00      0.97      0.98        30
#            freeze_account       0.85      0.97      0.91        30
#                  fun_fact       0.96      0.87      0.91        30
#                       gas       1.00      0.93      0.97        30
#                  gas_type       1.00      1.00      1.00        30
#                   goodbye       0.96      0.73      0.83        30
#                  greeting       1.00      0.90      0.95        30
#                  how_busy       1.00      0.63      0.78        30
#           how_old_are_you       0.90      0.93      0.92        30
#      improve_credit_score       1.00      0.97      0.98        30
#                    income       0.96      0.83      0.89        30
#   ingredient_substitution       0.96      0.83      0.89        30
#          ingredients_list       0.89      0.80      0.84        30
#                 insurance       1.00      0.97      0.98        30
#          insurance_change       0.96      0.90      0.93        30
#             interest_rate       0.81      0.83      0.82        30
#        international_fees       1.00      1.00      1.00        30
#        international_visa       1.00      1.00      1.00        30
#                jump_start       1.00      1.00      1.00        30
#          last_maintenance       1.00      0.93      0.97        30
#              lost_luggage       1.00      0.97      0.98        30
#                 make_call       0.72      0.70      0.71        30
#                     maybe       1.00      0.90      0.95        30
#           meal_suggestion       0.96      0.80      0.87        30
#           meaning_of_life       1.00      0.97      0.98        30
#    measurement_conversion       1.00      1.00      1.00        30
#          meeting_schedule       0.96      0.83      0.89        30
#               min_payment       1.00      1.00      1.00        30
#                       mpg       0.97      1.00      0.98        30
#                  new_card       0.97      0.93      0.95        30
#              next_holiday       0.94      1.00      0.97        30
#                 next_song       1.00      0.90      0.95        30
#                        no       1.00      0.97      0.98        30
#            nutrition_info       1.00      1.00      1.00        30
#            oil_change_how       0.94      1.00      0.97        30
#           oil_change_when       0.88      0.93      0.90        30
#                       oos       0.70      0.91      0.79      1000
#                     order       0.76      0.53      0.63        30
#              order_checks       1.00      1.00      1.00        30
#              order_status       0.93      0.90      0.92        30
#                  pay_bill       0.90      0.93      0.92        30
#                    payday       1.00      0.93      0.97        30
#                pin_change       1.00      0.83      0.91        30
#                play_music       0.87      0.67      0.75        30
#                 plug_type       1.00      0.97      0.98        30
#               pto_balance       0.97      0.93      0.95        30
#               pto_request       1.00      0.70      0.82        30
#        pto_request_status       0.86      0.80      0.83        30
#                  pto_used       0.97      1.00      0.98        30
#                    recipe       0.83      0.83      0.83        30
#            redeem_rewards       1.00      0.80      0.89        30
#                  reminder       1.00      0.90      0.95        30
#           reminder_update       0.96      0.80      0.87        30
#                    repeat       1.00      0.80      0.89        30
# replacement_card_duration       0.96      0.87      0.91        30
#              report_fraud       0.88      0.73      0.80        30
#          report_lost_card       1.00      0.87      0.93        30
#            reset_settings       1.00      1.00      1.00        30
#    restaurant_reservation       0.87      0.87      0.87        30
#        restaurant_reviews       0.86      0.63      0.73        30
#     restaurant_suggestion       0.96      0.87      0.91        30
#           rewards_balance       0.83      1.00      0.91        30
#                 roll_dice       1.00      1.00      1.00        30
#             rollover_401k       1.00      1.00      1.00        30
#                   routing       1.00      1.00      1.00        30
#      schedule_maintenance       0.96      0.87      0.91        30
#          schedule_meeting       0.83      0.97      0.89        30
#            share_location       0.96      0.83      0.89        30
#             shopping_list       0.88      0.50      0.64        30
#      shopping_list_update       0.57      0.67      0.62        30
#                smart_home       1.00      0.70      0.82        30
#                  spelling       0.93      0.87      0.90        30
#          spending_history       0.79      0.90      0.84        30
#               sync_device       1.00      1.00      1.00        30
#                     taxes       1.00      1.00      1.00        30
#                 tell_joke       1.00      1.00      1.00        30
#                      text       0.87      0.90      0.89        30
#                 thank_you       0.96      0.87      0.91        30
#                      time       0.90      0.90      0.90        30
#                     timer       1.00      0.93      0.97        30
#                  timezone       0.97      0.97      0.97        30
#               tire_change       0.97      1.00      0.98        30
#             tire_pressure       1.00      1.00      1.00        30
#                 todo_list       1.00      0.73      0.85        30
#          todo_list_update       0.75      0.70      0.72        30
#                   traffic       0.97      1.00      0.98        30
#              transactions       1.00      0.73      0.85        30
#                  transfer       1.00      0.93      0.97        30
#                 translate       1.00      0.60      0.75        30
#              travel_alert       1.00      0.93      0.97        30
#       travel_notification       1.00      0.93      0.97        30
#         travel_suggestion       0.91      1.00      0.95        30
#                      uber       0.97      1.00      0.98        30
#           update_playlist       0.93      0.87      0.90        30
#                 user_name       0.95      0.70      0.81        30
#                  vaccines       0.91      1.00      0.95        30
#                        w2       1.00      1.00      1.00        30
#                   weather       0.83      1.00      0.91        30
#     what_are_your_hobbies       0.96      0.87      0.91        30
#        what_can_i_ask_you       1.00      0.90      0.95        30
#         what_is_your_name       0.89      0.80      0.84        30
#                 what_song       0.97      0.97      0.97        30
#        where_are_you_from       1.00      0.90      0.95        30
#              whisper_mode       0.94      1.00      0.97        30
#       who_do_you_work_for       0.95      0.63      0.76        30
#              who_made_you       0.97      1.00      0.98        30
#                       yes       1.00      0.63      0.78        30
#
#                  accuracy                           0.89      5500
#                 macro avg       0.94      0.88      0.91      5500
#              weighted avg       0.90      0.89      0.89      5500

# %%
import joblib, json
from pathlib import Path

export_dir = Path("intent_oos_model")
export_dir.mkdir(exist_ok=True)
joblib.dump(clf, export_dir / "intent_oos_model.pkl")
joblib.dump(label_encoder, export_dir / "label_encoder.pkl")
sbert_model.save(str(export_dir / "sbert_model"))

config = {
    "oos_name": oos_name,
    "best_threshold": float(best_th),
    "num_classes": len(label_encoder.classes_),
    "class_names": label_encoder.classes_.tolist()
}

with open(export_dir / "oos_config.json", "w") as f:
    json.dump(config, f, indent=4)

print(" All components saved successfully in folder:", export_dir.resolve())

print("\nSaved files:")
for file in export_dir.iterdir():
    print(" -", file.name)
# Out:
# ✅ All components saved successfully in folder: /content/intent_oos_model
#
# Saved files:
#  - label_encoder.pkl
#  - intent_oos_model.pkl
#  - sbert_model
#  - oos_config.json

# %%
import shutil
from google.colab import files
model_dir = "intent_oos_model"

zip_path = shutil.make_archive(model_dir, "zip", model_dir)
print(" Model zipped successfully at:", zip_path)
files.download(zip_path)
# Out:
# 📦 Model zipped successfully at: /content/intent_oos_model.zip
